# %%
import numpy as np
import math
from IPython.core.debugger import set_trace

lowerBound, upperBound = -5, 10
x = np.random.uniform(low=lowerBound, high=upperBound, size=(10,))
N = len(x)


def f(x):
    #Sphere
    #Sum = 0
    #for i in range(0,N):
    #    Sum = Sum + (x[i])**2

    #Rosenbrock
    #Epsiolon = 10e-7
    #Sum = 0
    #for i in range(0, N-1):
    #    Sum = Sum + 100 * ((x[i])**2 - x[i+1])**2 + (x[i] - 1)**2
        
    #Ackley
    #Epsiolon = 10e-15
    Sum1, Sum2 = 0, 0
    for i in range(0,N):
        Sum1 = Sum1 + (x[i])**2
        Sum2 = Sum2 + math.cos(2*math.pi*x[i])
    Sum= -20.0*math.exp(-0.2*math.sqrt((1/N)*(Sum1)))-math.exp((1/N) * Sum2) + math.e + 20
    return Sum

l = [lowerBound for i in range(10)]
u = [upperBound for i in range(10)]

# %%
def _e(index,size):
    arr = np.zeros(size)
    arr[index] = 1.0
    return arr

# %%
def Delta(x):
    Sum = 0
    #no general, only box constraints
    for i in range(0,N):
        Sum = Sum + max(x[i]-u[i],0) + max(l[i]-x[i], 0)
    return Sum

# %%
def better(x,y):
    Dx = Delta(x)
    Dy = Delta(y)
    if(Dx < Dy):
        return True
    elif(Dx == Dy and f(x) < f(y)):
        return True
    else:
        return False

# %%
def findExtremes(s):
    Ds = np.empty([N+1])
    fs = np.empty([N+1])
    
    for i in range(0, N+1):
        Ds[i] = Delta(s[i])
        fs[i] = f(s[i])
    
    arg_b = np.argmin(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_b] and i != arg_b:
            if(fs[i] < fs[arg_b]):
                arg_b = i;
                
    arg_w = np.argmax(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_w] and i != arg_w:
            if(fs[i] > fs[arg_w]):
                arg_w = i;
    
    #mask the worst to find the second worst
    Ds[arg_w] = 0
    
    arg_sw = np.argmax(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_sw] and i != arg_w:
            if(fs[i] > fs[arg_sw]):
                arg_sw = i;
    
    return arg_b,arg_w,arg_sw

# %%
def centroid(s,argWorst):
    return np.mean(np.delete(s, argWorst), axis = 0)

# %%
def SimplexLocalSearch(x,Epsilon,Lambda,M,Alpha=1,Gamma=2,Beta=-0.5):
    N = len(x)
    s = np.empty([N+1,N])
    s[0] = x
    for j in range(1,N+1):
        s[j] = x + Lambda*(u[j-1]-l[j-1])*_e(j-1,N);
    k = 0
    
    
    argBest, argWorst, argSecondWorst = findExtremes(s)
    sBest, sWorst, sSecondWorst = s[argBest], s[argWorst], s[argSecondWorst]
    #set_trace()
    while abs(f(sBest) - f(sWorst)) > Epsilon and k < M and k < 1000:
        #set_trace()
        #if(k%1000 == 0):print(f(sBest),'\n')
        r = (1+Alpha)*centroid(s,argWorst) - Alpha*sWorst
        if(better(sBest,r) and better(r,sSecondWorst)):
            s[argWorst] = r
        elif(better(r,sBest)):
            e = (1+Gamma)*centroid(s,argWorst)-Gamma*sWorst
            if(better(e,r)):
                s[argWorst] = e
            else:
                s[argWorst] = r
        else:
            c = (1+Beta)*centroid(s,argWorst)-Beta*sWorst
            if(better(c,sWorst)):
                s[argWorst] = c
            else:
                for j in range(0,N+1):
                    s[j] = (s[j] + sBest)/2

        #set_trace()
        argBest, argWorst, argSecondWorst = findExtremes(s)
        sBest, sWorst, sSecondWorst = s[argBest], s[argWorst], s[argSecondWorst]
        k = k + 1
    #print(f(sBest))
    return sBest, k

# %%
def NonTabuSearch(Epsilon,EpsilonApostrophe,Lambda,M, Gamma = 2,Beta=-0.5, R = 2, Sigma = 1):
    k = 0
    it = 0
    x = np.random.uniform(low=lowerBound, high=upperBound, size=(10,))
    x, _k = SimplexLocalSearch(x,Epsilon,Lambda,M-k)
    k = k + _k
    xBest = np.zeros(10)
    xBest = xBest + x
    y = np.zeros(10)
    y = y + x
    running_first_time = True
    while(k < M):
        #set_trace()
        for i in range(1, R):
            x[i] = y[i] + Sigma*(u[i] - l[i])
            x, _k= SimplexLocalSearch(x,Epsilon,Lambda,M-k)
            k = k + _k
            if f(x) < f(xBest):
                print("***NEW BEST VALUE*** iteration: ", k, "| best found value: ", f(x))
                xBest, _k = SimplexLocalSearch(x,EpsilonApostrophe,Lambda,M-k)
                k = k + _k
            if running_first_time or f(x) < f(xWorst):
                running_first_time = False
                xWorst = np.zeros(10)
                xWorst = xWorst + x
        y = np.zeros(10)
        y = y + xWorst
        if( k//1000 > it):
            it = k//1000
            print("iteration:", it * 1000, "| best found value: ", f(xBest))
        
    return xBest

# %%
Lambda = 10
M = 100000
Epsilon = 10e-10
#set_trace()
EpsilonApostrophe = 10e-20
x_best = NonTabuSearch(Epsilon,EpsilonApostrophe,Lambda,M)
print(f(x_best))
print(x_best)
# Out:
# ***NEW BEST VALUE*** iteration:  1652 | best found value:  2.9365416764903784e-09
# iteration: 2000 | best found value:  3.552713678800501e-15
# iteration: 3000 | best found value:  3.552713678800501e-15
# iteration: 4000 | best found value:  3.552713678800501e-15
# iteration: 5000 | best found value:  3.552713678800501e-15
# iteration: 6000 | best found value:  3.552713678800501e-15
# iteration: 7000 | best found value:  3.552713678800501e-15
# iteration: 8000 | best found value:  3.552713678800501e-15
# iteration: 9000 | best found value:  3.552713678800501e-15
# iteration: 10000 | best found value:  3.552713678800501e-15
# iteration: 11000 | best found value:  3.552713678800501e-15
# iteration: 12000 | best found value:  3.552713678800501e-15
# iteration: 13000 | best found value:  3.552713678800501e-15
# iteration: 14000 | best found value:  3.552713678800501e-15
# iteration: 15000 | best found value:  3.552713678800501e-15
# iteration: 16000 | best found value:  3.552713678800501e-15
# iteration: 17000 | best found value:  3.552713678800501e-15
# iteration: 18000 | best found value:  3.552713678800501e-15
# iteration: 19000 | best found value:  3.552713678800501e-15
# iteration: 20000 | best found value:  3.552713678800501e-15
# iteration: 21000 | best found value:  3.552713678800501e-15
# iteration: 22000 | best found value:  3.552713678800501e-15
# iteration: 23000 | best found value:  3.552713678800501e-15
# iteration: 24000 | best found value:  3.552713678800501e-15
# iteration: 25000 | best found value:  3.552713678800501e-15
# iteration: 26000 | best found value:  3.552713678800501e-15
# iteration: 27000 | best found value:  3.552713678800501e-15
# iteration: 28000 | best found value:  3.552713678800501e-15
# iteration: 29000 | best found value:  3.552713678800501e-15
# iteration: 30000 | best found value:  3.552713678800501e-15
# iteration: 31000 | best found value:  3.552713678800501e-15
# iteration: 32000 | best found value:  3.552713678800501e-15
# iteration: 33000 | best found value:  3.552713678800501e-15
# iteration: 34000 | best found value:  3.552713678800501e-15
# iteration: 35000 | best found value:  3.552713678800501e-15
# iteration: 36000 | best found value:  3.552713678800501e-15
# iteration: 37000 | best found value:  3.552713678800501e-15
# iteration: 38000 | best found value:  3.552713678800501e-15
# iteration: 39000 | best found value:  3.552713678800501e-15
# iteration: 40000 | best found value:  3.552713678800501e-15
# iteration: 41000 | best found value:  3.552713678800501e-15
# iteration: 42000 | best found value:  3.552713678800501e-15
# iteration: 43000 | best found value:  3.552713678800501e-15
# iteration: 44000 | best found value:  3.552713678800501e-15
# iteration: 45000 | best found value:  3.552713678800501e-15
# iteration: 46000 | best found value:  3.552713678800501e-15
# iteration: 47000 | best found value:  3.552713678800501e-15
# iteration: 48000 | best found value:  3.552713678800501e-15
# iteration: 49000 | best found value:  3.552713678800501e-15
# iteration: 50000 | best found value:  3.552713678800501e-15
# iteration: 51000 | best found value:  3.552713678800501e-15
# iteration: 52000 | best found value:  3.552713678800501e-15
# iteration: 53000 | best found value:  3.552713678800501e-15
# iteration: 54000 | best found value:  3.552713678800501e-15
# iteration: 55000 | best found value:  3.552713678800501e-15
# iteration: 56000 | best found value:  3.552713678800501e-15
# iteration: 57000 | best found value:  3.552713678800501e-15
# iteration: 58000 | best found value:  3.552713678800501e-15
# iteration: 59000 | best found value:  3.552713678800501e-15
# iteration: 60000 | best found value:  3.552713678800501e-15
# iteration: 61000 | best found value:  3.552713678800501e-15
# iteration: 62000 | best found value:  3.552713678800501e-15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18709/682513553.py in <module>
#       4 #set_trace()
#       5 EpsilonApostrophe = 10e-20
# ----> 6 x_best = NonTabuSearch(Epsilon,EpsilonApostrophe,Lambda,M)
#       7 print(f(x_best))
#       8 print(x_best)
#
# /tmp/ipykernel_18709/2534170146.py in NonTabuSearch(Epsilon, EpsilonApostrophe, Lambda, M, Gamma, Beta, R, Sigma)
#      14         for i in range(1, R):
#      15             x[i] = y[i] + Sigma*(u[i] - l[i])
# ---> 16             x, _k= SimplexLocalSearch(x,Epsilon,Lambda,M-k)
#      17             k = k + _k
#      18             if f(x) < f(xBest):
#
# /tmp/ipykernel_18709/692961366.py in SimplexLocalSearch(x, Epsilon, Lambda, M, Alpha, Gamma, Beta)
#      15         #if(k%1000 == 0):print(f(sBest),'\n')
#      16         r = (1+Alpha)*centroid(s,argWorst) - Alpha*sWorst
# ---> 17         if(better(sBest,r) and better(r,sSecondWorst)):
#      18             s[argWorst] = r
#      19         elif(better(r,sBest)):
#
# /tmp/ipykernel_18709/1837904803.py in better(x, y)
#       4     if(Dx < Dy):
#       5         return True
# ----> 6     elif(Dx == Dy and f(x) < f(y)):
#       7         return True
#       8     else:
#
# /tmp/ipykernel_18709/2711917639.py in f(x)
#      24     Sum1, Sum2 = 0, 0
#      25     for i in range(0,N):
# ---> 26         Sum1 = Sum1 + (x[i])**2
#      27         Sum2 = Sum2 + math.cos(2*math.pi*x[i])
#      28     Sum= -20.0*math.exp(-0.2*math.sqrt((1/N)*(Sum1)))-math.exp((1/N) * Sum2) + math.e + 20
#
# KeyboardInterrupt:
