# %%
import numpy as np
import math
from IPython.core.debugger import set_trace

lowerBound, upperBound = -5, 10
x = np.random.uniform(low=lowerBound, high=upperBound, size=(10,))
N = len(x)


def f(x):
    #Sphere
    # x in interval [-30, -30]
    #Sum = 0
    #for i in range(0,N):
    #    Sum = Sum + (x[i])**2

    #Rosenbrock
    # x in interval [-30, -30]
    #Sum = 0
    #for i in range(0, N-1):
    #    Sum = Sum + 100 * ((x[i])**2 - x[i+1])**2 + (x[i] - 1)**2
        
    #Ackley
    # x in interval [-5, -10]
    Sum1, Sum2 = 0, 0
    for i in range(0,N):
        Sum1 = Sum1 + (x[i])**2
        Sum2 = Sum2 + math.cos(2*math.pi*x[i])
    Sum= -20.0*math.exp(-0.2*math.sqrt((1/N)*(Sum1)))-math.exp((1/N) * Sum2) + math.e + 20
    return Sum

l = [lowerBound for i in range(10)]
u = [upperBound for i in range(10)]

# %%
def _e(index,size):
    arr = np.zeros(size)
    arr[index] = 1.0
    return arr

# %%
def Delta(x):
    Sum = 0
    #no general, only box constraints
    for i in range(0,N):
        Sum = Sum + max(x[i]-u[i],0) + max(l[i]-x[i], 0)
    return Sum

# %%
def better(x,y):
    Dx = Delta(x)
    Dy = Delta(y)
    if(Dx < Dy):
        return True
    elif(Dx == Dy and f(x) < f(y)):
        return True
    else:
        return False

# %%
def findExtremes(s):
    Ds = np.empty([N+1])
    fs = np.empty([N+1])
    
    for i in range(0, N+1):
        Ds[i] = Delta(s[i])
        fs[i] = f(s[i])
    
    arg_b = np.argmin(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_b] and i != arg_b:
            if(fs[i] < fs[arg_b]):
                arg_b = i;
                
    arg_w = np.argmax(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_w] and i != arg_w:
            if(fs[i] > fs[arg_w]):
                arg_w = i;
    
    #mask the worst to find the second worst
    Ds[arg_w] = 0
    
    arg_sw = np.argmax(Ds)
    for i in range(0, N+1):
        if Ds[i] == Ds[arg_sw] and i != arg_w:
            if(fs[i] > fs[arg_sw]):
                arg_sw = i;
    
    return arg_b,arg_w,arg_sw

# %%
def centroid(s,argWorst):
    return np.mean(np.delete(s, argWorst), axis = 0)

# %%
def SimplexLocalSearch(x,Epsilon,Lambda,M,Alpha=1,Gamma=2,Beta=-0.5):
    N = len(x)
    s = np.empty([N+1,N])
    s[0] = x
    for j in range(1,N+1):
        s[j] = x + Lambda*(u[j-1]-l[j-1])*_e(j-1,N);
    k = 0
    
    
    argBest, argWorst, argSecondWorst = findExtremes(s)
    sBest, sWorst, sSecondWorst = s[argBest], s[argWorst], s[argSecondWorst]
    #set_trace()
    while abs(f(sBest) - f(sWorst)) > Epsilon and k < M and k < 1000:
        #set_trace()
        #if(k%1000 == 0):print(f(sBest),'\n')
        r = (1+Alpha)*centroid(s,argWorst) - Alpha*sWorst
        if(better(sBest,r) and better(r,sSecondWorst)):
            s[argWorst] = r
        elif(better(r,sBest)):
            e = (1+Gamma)*centroid(s,argWorst)-Gamma*sWorst
            if(better(e,r)):
                s[argWorst] = e
            else:
                s[argWorst] = r
        else:
            c = (1+Beta)*centroid(s,argWorst)-Beta*sWorst
            if(better(c,sWorst)):
                s[argWorst] = c
            else:
                for j in range(0,N+1):
                    s[j] = (s[j] + sBest)/2

        #set_trace()
        argBest, argWorst, argSecondWorst = findExtremes(s)
        sBest, sWorst, sSecondWorst = s[argBest], s[argWorst], s[argSecondWorst]
        k = k + 1
    #print(f(sBest))
    return sBest, k, s, argBest, argWorst, argSecondWorst

# %%
def DirectionalEscape(Epsilon,EpsilonApostrophe,Lambda,M, Gamma = 2,Beta=-0.5):
    k = 0
    it = 0
    x = np.random.uniform(low=lowerBound, high=upperBound, size=(10,))
    while(k < M):
        #set_trace()
        temp, _k, s, argBest, argWorst, argSecondWorst = SimplexLocalSearch(x,Epsilon,Lambda,M-k)
        x = np.zeros(N)
        x = x + temp
        
        k = k + _k
        try: xBest
        except NameError: xBest = None
        
        if xBest is None or f(x) < f(xBest):
            temp, _k, s, argBest, argWorst, argSecondWorst = SimplexLocalSearch(x,EpsilonApostrophe,Lambda,M-k)
            xBest = np.zeros(N)
            xBest = xBest + temp
            k = k + _k
            print("***NEW BEST VALUE*** iteration: ", k, "| best found value: ", f(xBest))
            
        if xBest is not None and k//1000 > it:
            it = k//1000
            print("iteration:", it * 1000, "| best found value: ", f(xBest))
            
            if f(xBest) < 1:
                for i in range(0,N):
                    s[i][i] = s[i][i] + 10e-2*f(xBest)
            else:
                for i in range(0,N):
                    s[i][i] = s[i][i] + 10e-5*f(xBest)
            
            argBest, argWorst, argSecondWorst = findExtremes(s)
            
            xWorst = np.zeros(N)
            xWorst = xWorst + x
        while Delta(x) == 0 and f(x) <= f(xWorst):
            xWorst = np.zeros(N)
            xWorst = xWorst + x
            argBest, argWorst, argSecondWorst = findExtremes(s)
            x = Gamma*s[argBest] + (1-Gamma) * centroid(s,argBest)
            s[argBest] = np.zeros(N)
            s[argBest] = s[argBest] + x
            
        
        
    return xBest

# %%
Lambda = 10
M = 100000
Epsilon = 10e-3
#set_trace()
EpsilonApostrophe = 0
print(DirectionalEscape(Epsilon,EpsilonApostrophe,Lambda,M))
# Out:
# ***NEW BEST VALUE*** iteration:  1067 | best found value:  2.1316282072803006e-14
# iteration: 1000 | best found value:  2.1316282072803006e-14
# iteration: 2000 | best found value:  2.1316282072803006e-14
# iteration: 3000 | best found value:  2.1316282072803006e-14
# iteration: 4000 | best found value:  2.1316282072803006e-14
# iteration: 5000 | best found value:  2.1316282072803006e-14
# iteration: 6000 | best found value:  2.1316282072803006e-14
# iteration: 7000 | best found value:  2.1316282072803006e-14
# iteration: 8000 | best found value:  2.1316282072803006e-14
# iteration: 9000 | best found value:  2.1316282072803006e-14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11450/3580703135.py in <module>
#       4 #set_trace()
#       5 EpsilonApostrophe = 0
# ----> 6 print(DirectionalEscape(Epsilon,EpsilonApostrophe,Lambda,M))
#
# /tmp/ipykernel_11450/4081578406.py in DirectionalEscape(Epsilon, EpsilonApostrophe, Lambda, M, Gamma, Beta)
#       5     while(k < M):
#       6         #set_trace()
# ----> 7         temp, _k, s, argBest, argWorst, argSecondWorst = SimplexLocalSearch(x,Epsilon,Lambda,M-k)
#       8         x = np.zeros(N)
#       9         x = x + temp
#
# /tmp/ipykernel_11450/801332768.py in SimplexLocalSearch(x, Epsilon, Lambda, M, Alpha, Gamma, Beta)
#      15         #if(k%1000 == 0):print(f(sBest),'\n')
#      16         r = (1+Alpha)*centroid(s,argWorst) - Alpha*sWorst
# ---> 17         if(better(sBest,r) and better(r,sSecondWorst)):
#      18             s[argWorst] = r
#      19         elif(better(r,sBest)):
#
# /tmp/ipykernel_11450/1837904803.py in better(x, y)
#       1 def better(x,y):
#       2     Dx = Delta(x)
# ----> 3     Dy = Delta(y)
#       4     if(Dx < Dy):
#       5         return True
#
# /tmp/ipykernel_11450/1622934442.py in Delta(x)
#       3     #no general, only box constraints
#       4     for i in range(0,N):
# ----> 5         Sum = Sum + max(x[i]-u[i],0) + max(l[i]-x[i], 0)
#       6     return Sum
#
# KeyboardInterrupt:
